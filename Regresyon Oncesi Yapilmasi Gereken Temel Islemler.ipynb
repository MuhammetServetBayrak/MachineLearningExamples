# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.scatter([1,2,3,4,5,6],[1,4,9,16,25,36])
plt.xlabel('X Ekseni')
plt.ylabel('Y Ekseni')
plt.show()

# %%
plt.plot([1,2,3,4,5,6],[1,4,9,16,25,36])
plt.xlabel('X Ekseni')
plt.ylabel('Y Ekseni')
plt.show()

# %%
data=pd.read_csv("C:/Users/muham/maas.csv") #excelden dosyayı çekme işlemi
data.head()
# Out:
#    tecrube  maas
# 0      1.1  3934
# 1      1.3  4620
# 2      1.5  3773
# 3      2.0  4352
# 4      2.2  3989

# %%
data.tail()
# Out:
#     tecrube   maas
# 25      9.0  10558
# 26      9.5  11696
# 27      9.6  11263
# 28     10.3  12239
# 29     10.5  12187

# %%
x=data
y=data #yukarıdaki veriyi düzgün çekemediğim için buraya direk datayı verdim

# %%
x=data.iloc[:,0].values.reshape(-1,1)
y=data.iloc[:,1].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
#normalizasyon işlemi
xnorm=(x-np.min(x))/(np.max(x)-np.min(x))
#bu işlemin riski veri setinde en büyük değer 10000 olduğunu varsayım ve diğer 9 değerin çok daha düşük(200 vs.) olduğunu varsayarsak
#norm çalışmasından sonra en büüyk değer 1 diğerleri ise max 0.100 vs olacak
xnorm
# Out:
# array([[0.        ],
#        [0.0212766 ],
#        [0.04255319],
#        [0.09574468],
#        [0.11702128],
#        [0.19148936],
#        [0.20212766],
#        [0.22340426],
#        [0.22340426],
#        [0.27659574],
#        [0.29787234],
#        [0.30851064],
#        [0.30851064],
#        [0.31914894],
#        [0.36170213],
#        [0.40425532],
#        [0.42553191],
#        [0.44680851],
#        [0.5106383 ],
#        [0.5212766 ],
#        [0.60638298],
#        [0.63829787],
#        [0.72340426],
#        [0.75531915],
#        [0.80851064],
#        [0.84042553],
#        [0.89361702],
#        [0.90425532],
#        [0.9787234 ],
#        [1.        ]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
xtrain1=sc.fit_transform(xtrain)
xtest1=sc.transform(xtest)

# %%
xtrain1
# Out:
# array([[-1.36666691],
#        [-0.96398827],
#        [ 0.09761906],
#        [-0.70773822],
#        [-0.26845243],
#        [-0.30505958],
#        [ 1.12261925],
#        [-1.29345261],
#        [-1.22023831],
#        [ 1.52529789],
#        [-1.03720256],
#        [ 0.82976205],
#        [ 1.70833364],
#        [ 0.39047626],
#        [ 2.07440513],
#        [ 0.7199406 ],
#        [-0.59791677],
#        [-0.34166673],
#        [-0.12202383],
#        [ 0.42708341],
#        [-0.67113107]])

# %%
xtest1
# Out:
# array([[ 1.74494079],
#        [ 0.02440477],
#        [ 1.23244069],
#        [ 0.17083336],
#        [-0.59791677],
#        [-0.41488103],
#        [ 2.00119083],
#        [ 1.41547644],
#        [-0.30505958]])
